# %% [markdown]
# ### Empire State Building Probability
#
# What are the odds that you'll reach 60 steps high on the Empire State Building?
# This is based for a 100 times roll of dice
# * If dice is 1 or 2, you go one step down.
# * if dice is 3, 4 or 5, you go one step up.
# * Else, you throw the dice again. The number of eyes is the number of steps you go up.
#
# Implement clumsiness, with 0.1% of falling down
#
# --
# Requirements:
#
# **Random Walk Simulation:**
# - Title: "Random Walk Simulation", font size = 20, font weight = 800,  location, center
# - label y-axis and x-axis
# - limit of the grid for y-axis: 150, x-axis=100
#
# **Histogram:**
# - Title: "Step Height Distribution", font size = 12 , location = left, font weight = 300
# - label y-axis and x-axis
#     label of y axis, extra small, semi-bold
#     label of x axis, font size 8, demi-bold
# - add y-axis grid

# %%
# July 2 Workoutsj

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(123)

allwalks = []

for i in range(500):
    randomwalk = [0]
    
    for j in range(100):
        steps = randomwalk[-1]
        dice = np.random.randint(1, 7)
        
        if dice <= 2:
            steps = max(0, steps-1)
        elif dice <= 5:
            steps += 1
        else:
            steps += np.random.randint(1, 7)
        if np.random.rand() <= 0.001:
            steps = 0
        
        randomwalk.append(steps)
        
    allwalks.append(randomwalk)
    
np_allwalks = np.array(allwalks)
tnp_allwalks = np.column_stack(np_allwalks)

plt.plot(tnp_allwalks)
plt.title("Random Walk Simulation", fontsize = 20, fontweight = 300)
plt.ylabel("Step Height")
plt.xlabel("Number of Dice Throws")
plt.axis([0, 100, 0, 150])
plt.show()

ends = tnp_allwalks[-1]
plt.hist(ends)
plt.title('Distribution of Step Height', loc = 'left', fontweight = 300)
plt.ylabel('Step Height', fontsize = 'x-small', fontweight = 'semibold')
plt.xlabel('Number of Occurrences', fontsize = 8, fontweight = 'demibold')
plt.grid(True, axis='y')
plt.show()


stepheight = np.count_nonzero(ends >= 60)
print("The probability of going 60 steps or higher is: " + str(100*(stepheight/500)) )
# Out:
# The probability of going 60 steps or higher is: 78.4

# %%
# %pastebin
# Out:
# '' was not found in history, as a file, url, nor in the user namespace.

# %%
#July 1 Workouts

# %%
## %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(123)

allwalks = []

for i in range(500):
    random_walk = [0]
    
    for j in range(100):
        dice = np.random.randint(1,7)
        steps = random_walk[-1]
        
        if dice <= 2:
            steps = max(0, steps-1)
        elif dice <= 5:
            steps = steps + 1
        else:
            steps += np.random.randint(1,7)
        if np.random.rand() <= 0.001:
            steps = 0
        random_walk.append(steps)
    allwalks.append(random_walk)

np_allwalks = np.array(allwalks)
tnp_allwalks = np.column_stack(np_allwalks)


plt.plot(tnp_allwalks)
plt.title("Random Walk Simulation", fontsize = 20, fontweight = 10)
plt.ylabel("Step Height")
plt.xlabel("Dice Throws")
plt.axis([0, 100, 0, 150])
plt.show()



ends = tnp_allwalks[-1]
plt.hist(ends)
plt.title("Step Height Distribution", fontsize = 'large', fontweight = 800, loc = 'left')
plt.ylabel("Step Height", fontsize = 'x-small', fontweight = 'semibold')
plt.xlabel("Number of Occurrences", fontsize = 8, fontweight='demibold')
plt.grid(True, axis = 'y')
plt.show()


step_height = np.count_nonzero(ends >= 60)
print(step_height/500)
# Out:
# 0.784

# %%
plt.title??

# %%
plt.text??

# %%
plt.artist??
# Out:
# Object `plt.artist` not found.

# %%
#June 30 Workout

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(123)
allwalks = []

for i in range(500):
    random_walk = [0]
        
    for j in range(100):
        steps = random_walk[-1]
        dice = np.random.randint(1,7)
        
        if dice <= 2:
            steps = max(0, steps -1)
        elif dice <=5:
            steps += 1
        else:
            steps += np.random.randint(1,7)
        if np.random.rand() <= 0.001:
            steps = 0
        
        random_walk.append(steps)
    allwalks.append(random_walk)

np_allwalks = np.array(allwalks)
tnp_allwalks = np.column_stack(np_allwalks)

plt.plot(tnp_allwalks)
plt.title("Random Walk Simulation", fontsize=20)
plt.ylabel("Step Height")
plt.xlabel("Number of Dice Throws")
plt.axis([0, 100, 0, 150])
plt.show()

ends = tnp_allwalks[-1]
plt.hist(ends)
plt.title("Step Height Distribution", fontweight=1000, fontsize=10, loc="left")
plt.ylabel("Step Height", rotation='vertical')
plt.xlabel("Count of Step Height Occurrence")
plt.grid(True, axis="y")
plt.show()

stepheight_count = np.count_nonzero( ends >= 60)
print(stepheight_count / 500)
# Out:
# 0.784

# %%
plt.ylabel??

# %%
# July 29, 2019 Workout
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(123)

allwalks = []

for i in range(500):
    random_walk = [0]
    
    for x in range(100):
        steps = random_walk[-1]
        dice = np.random.randint(1,7)
        
        if dice <= 2:
            steps = max(0, steps -1)
        elif dice <= 5:
            steps += 1
        else:
            steps += np.random.randint(1,7)
        if np.random.rand() <= 0.001:
            steps = 0
        
        random_walk.append(steps)
    
    allwalks.append(random_walk)

np_allwalks = np.array(allwalks)
tnp_allwalks =  np.column_stack(np_allwalks)

plt.plot(tnp_allwalks)
plt.title("Random Walk Simulation", fontsize=20)
plt.ylabel("Step Height")
plt.xlabel("Number of Dice Throws")
plt.axis([0, 100, 0, 150])
plt.show()


ends = tnp_allwalks[-1]
plt.hist(ends)
plt.title("Step Height Distribution", fontweight = 1000, fontsize = 10, loc='left')
plt.ylabel("Step Height")
plt.xlabel("Number of Occurrence")
plt.grid(True, axis='y')
plt.show()

step_height = np.count_nonzero( ends >= 60)
print(step_height/500)
# Out:
# 0.784

# %%
plt??10

# %%
np.shape(tnp_allwalks)
# Out:
# (101, 500)

# %%
np.shape(np_allwalks)
# Out:
# (500, 101)

# %%
tnp_allwalks
# Out:
# array([[ 0,  0,  0, ...,  0,  0,  0],
#        [ 3,  5,  0, ...,  1,  1,  1],
#        [ 2,  4,  1, ...,  2,  0,  0],
#        ...,
#        [70, 90, 80, ..., 93, 59, 60],
#        [69, 93, 81, ..., 92, 58, 61],
#        [70, 94, 82, ..., 91, 57, 65]])

# %%
# June 28, 2018 Workout
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(123)

all_walk = []

for j in range(500):
    random_walk = [0]
    
    for i in range(100):
        dice = np.random.randint(1,7)
        steps = random_walk[-1]
        
        if dice <= 2:
            steps = max(0, steps-1)
        elif dice <=5:
            steps += 1
        else:
            steps += np.random.randint(1,7)
        if np.random.rand() <= 0.001:
            steps = 0
        
        random_walk.append(steps)
    all_walk.append(random_walk) 

np_allwalk = np.array(all_walk)
tnp_allwalk = np.column_stack(np_allwalk)

plt.plot(tnp_allwalk)
plt.title("Random Walk Simulation", fontsize = 20)
plt.ylabel("Step Height")
plt.xlabel("Number of Dice Throws")
plt.axis([0, 100, 0, 150])
plt.show()

ends = tnp_allwalk[-1]
plt.hist(ends)
plt.title("Step Height Simulation", loc="left", fontweight=1000)
plt.ylabel("Step Height")
plt.xlabel("Number of Occurrence")
plt.grid(True, axis = 'y')
plt.show()

step_height = np.count_nonzero(ends >= 60)
print("Probability of ending 60 steps high or above: " + str((step_height/500)*100) + "%")
# Out:
# Probability of ending 60 steps high or above: 78.4%

# %%
plt.grid??

# %%
#Coding workout June 27, 2019
plt.ylabel??

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(123)

all_walk = []

for j in range(500):
    random_walk = [0]
    
    for i in range(100):
        
        steps = random_walk[-1]
        dice = np.random.randint(1,7)
        
        if dice <= 2:
            steps = max(0, steps -1)
        elif dice <=5:
            steps += 1
        else:
            steps += np.random.randint(1,7)
        if np.random.rand() <= 0.001:
            steps = 0
        
        random_walk.append(steps)
    all_walk.append(random_walk)

np_allwalk = np.array(all_walk)
tnp_allwalk = np.column_stack(np_allwalk)

plt.plot(tnp_allwalk)
plt.title("Random Walk Simulation", fontsize=20)
plt.xlabel("Number of Dice Throws")
plt.ylabel("Step Height")
plt.axis([0,100,0,150])
plt.grid(True, axis ='x')
#plt.tick_params(axis='both', which='minor', labelsize=8)
#plt.axes().get_xaxis().set_visible(True)
plt.show()    
    
ends = tnp_allwalk[-1]    
plt.hist(ends)
plt.title("Histogram",loc="left", fontsize=15, fontweight=1000)
plt.ylabel("Step Height")
plt.xlabel("Number of Walks")
plt.show()

step_height = np.count_nonzero( ends >= 60)
print(step_height / 500)
# Out:
# 0.784

# %%
plt.grid??

# %%
#June 26, 2019 WOrkout
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(123)

all_walk = []

for j in range(500):
    random_walk = [0]
    
    for i in range(100):
        steps = random_walk[-1] 
        dice = np.random.randint(1,7)
        
        if dice <= 2:
            steps = max(0, steps-1)
        elif dice <= 5:
            steps += 1
        else:
            steps += np.random.randint(1,7)
        if np.random.rand() <= 0.001:
            steps = 0
            
        random_walk.append(steps)
    all_walk.append(random_walk)

np_allwalks = np.array(all_walk)
tnp_allwalks = np.column_stack(np_allwalks)

plt.plot(tnp_allwalks)
plt.show()

ends = tnp_allwalks[-1]

plt.hist(ends)
plt.show()

step_height = np.count_nonzero(ends >= 60)
print(step_height/500)
# Out:
# 0.784

# %%
#June 25 coding workout
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(123)

all_walks = []


for j in range(500):
    random_walk = [0]
    
    for i in range(100):
        
        steps = random_walk[-1]
        
        dice = np.random.randint(1,7)
        
        if dice <= 2:
            steps = max(0, steps-1)
            
        elif dice <=5:
            steps += 1
            
        else:
            steps += np.random.randint(1,7)
        
        if np.random.rand() <= 0.001:
            steps = 0
            
        random_walk.append(steps)

    all_walks.append(random_walk)

np_allwalks = np.array(all_walks)
tnp_allwalks = np.column_stack(all_walks)

plt.plot(tnp_allwalks)
plt.show()

ends = tnp_allwalks[-1]
plt.hist(ends)
plt.show()


step_height = np.count_nonzero( ends >= 60)
print(step_height/500)
# Out:
# 0.784

# %%
# June 24, 2019 Workout 
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(123)

all_walks = []


for j in range(500):
    random_walk = [0]
    
    for i in range(100):
        
        steps = random_walk[-1]
        
        dice = np.random.randint(1,7)
        
        if dice <= 2:
            steps = max(0, steps-1)
            
        elif dice <= 5:
            steps += 1
        
        else:
            steps += np.random.randint(1,7)
        
        if np.random.rand() <= 0.001:
            steps = 0
            
        random_walk.append(steps)
    
    all_walks.append(random_walk)

np_allwalks = np.array(all_walks)
tnp_allwalks = np.column_stack(np_allwalks)

plt.plot(tnp_allwalks)
plt.show()

ends = tnp_allwalks[-1]

plt.hist(ends)
plt.show()


stepsheight = np.count_nonzero(ends >= 60)
print (stepsheight/500)
# Out:
# 0.784

# %%
np.random.rand()
# Out:
# 0.5627017123861096

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(123)


all_walk = []


for i in range(500):
    random_walk = [0]
    
    for i in range(100):
        
        steps = random_walk[-1]
        dice = np.random.randint(1,7)
        
        if dice <= 2:
            steps = max(0, steps -1)
        
        elif dice <= 5:
            steps += 1
            
        else:
            steps += np.random.randint(1,7)
        
        if np.random.rand() < 0.001:
            steps = 0
            
        random_walk.append(steps)
        
    all_walk.append(random_walk)

np_all_walk = np.array(all_walk)
tnp_all_walk = np.column_stack(np_all_walk)

plt.plot(np_all_walk)
plt.title("Test Plot")
plt.show()
plt.plot(tnp_all_walk)
plt.title("Simulation of Random Walks")
plt.show()

ends = tnp_all_walk[-1]
plt.hist(ends)
plt.title("Histogram")
plt.show()

# %%
steps_60 = np.count_nonzero( ends >= 60)

# %%
steps_60/500
# Out:
# 0.784
