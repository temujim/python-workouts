# %%
# import pandas fiboworkout 8
# Planned date: 5/5, executed 5/9

# %%
import pandas as pd

# ********

# %%
# ********

# %%
brix_df = pd.read_csv("/home/barca/Python_Workouts/00 Concepts, Modules, Packages/00-00 datasets/brics.csv", index_col = 0)
brix_df

# print("test")

# ********
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
# ********


for index, col in brix_df.iterrows():

    print("{} - {}, {}".format(index, col['country'], col['capital']))

# ********
# Out:
# BR - Brazil, Brasilia
# RU - Russia, Moscow
# IN - India, New Delhi
# CH - China, Beijing
# SA - South Africa, Pretoria

# %%
# ********

for index, col in brix_df.iterrows():
    print(col['country'].upper())

# ********
# Out:
# BRAZIL
# RUSSIA
# INDIA
# CHINA
# SOUTH AFRICA

# %%
# ********

brix_df
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
brix_df['capital']['BR']


# - - - -
# Out:
# 'Brasilia'

# %%
# - - - -
print(brix_df.loc['BR',['capital']])
type(brix_df.loc['BR',['capital']])


# - - - -
# Out:
# capital    Brasilia
# Name: BR, dtype: object
# pandas.core.series.Series

# %%
# - - - -
print(brix_df.loc[['BR'], ['capital']])
type(brix_df.loc[['BR'], ['capital']])


# ********
# Out:
# capital
# BR  Brasilia
# pandas.core.frame.DataFrame

# %%
# ********

# - - - -

# %%
brix_df['capital']


# - - - -
# Out:
# BR     Brasilia
# RU       Moscow
# IN    New Delhi
# CH      Beijing
# SA     Pretoria
# Name: capital, dtype: object

# %%
brix_df.loc[:, 'capital']

# - - - -
# Out:
# BR     Brasilia
# RU       Moscow
# IN    New Delhi
# CH      Beijing
# SA     Pretoria
# Name: capital, dtype: object

# %%
brix_df.iloc[:, 0]

#
# ********
# Out:
# BR          Brazil
# RU          Russia
# IN           India
# CH           China
# SA    South Africa
# Name: country, dtype: object

# %%
# ********

brix_df

# - - - -
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
# brix_df.loc[:]['BR']
'''
This is not possible direct df slicing is like a dictionary.
This will be explain in-depth under #2 sample

'''


# - - - -
# Out:
# '\nThis is not possible direct df slicing is like a dictionary.\nThis will be explain in-depth under #2 sample\n\n'

# %%
brix_df.loc['BR']

# - - - -
# Out:
# country         Brazil
# capital       Brasilia
# area             8.516
# population       200.4
# Name: BR, dtype: object

# %%
brix_df.iloc[0]
# Out:
# country         Brazil
# capital       Brasilia
# area             8.516
# population       200.4
# Name: BR, dtype: object

# %%
# ********

# %%
# ********

for row, col in brix_df.iterrows():
    brix_df.loc[row, 'COUNTRY'] = col['country'].upper()

print(brix_df)


# ********
# Out:
# country    capital    area  population       COUNTRY
# BR        Brazil   Brasilia   8.516      200.40        BRAZIL
# RU        Russia     Moscow  17.100      143.50        RUSSIA
# IN         India  New Delhi   3.286     1252.00         INDIA
# CH         China    Beijing   9.597     1357.00         CHINA
# SA  South Africa   Pretoria   1.221       52.98  SOUTH AFRICA

# %%
# ********

# %%
brix_df['CAPITAL'] = brix_df['capital'].str.upper()
print(brix_df)
# Out:
# country    capital    area  population       COUNTRY    CAPITAL
# BR        Brazil   Brasilia   8.516      200.40        BRAZIL   BRASILIA
# RU        Russia     Moscow  17.100      143.50        RUSSIA     MOSCOW
# IN         India  New Delhi   3.286     1252.00         INDIA  NEW DELHI
# CH         China    Beijing   9.597     1357.00         CHINA    BEIJING
# SA  South Africa   Pretoria   1.221       52.98  SOUTH AFRICA   PRETORIA

# %%
# modify the display of dataframe
# pd.set_option('display.max_colwidth', 15)
pd.set_option('display.max_columns', 0)
# pd.set_option('display.large_repr', 0)

brix_df['lenCap'] = brix_df['capital'].apply(lambda x: len(x))
brix_df





# ----------------------------------------------------------------------
# Out:
#          country    capital    area  ...         COUNTRY    CAPITAL lenCap
# BR        Brazil   Brasilia   8.516  ...          BRAZIL   BRASILIA      8
# RU        Russia     Moscow  17.100  ...          RUSSIA     MOSCOW      6
# IN         India  New Delhi   3.286  ...           INDIA  NEW DELHI      9
# CH         China    Beijing   9.597  ...           CHINA    BEIJING      7
# SA  South Africa   Pretoria   1.221  ...    SOUTH AFRICA   PRETORIA      8
#
# [5 rows x 7 columns]

# %%
# ----------------------------------------------------------------------

# ********

# %%
# ********

# dictionary of list
d = {'col1': [1, 2, 3],
     'col2': [4, 5, 6],
     'col3': [7, 8, 9]}

print(d)


# - - - -
# Out:
# {'col1': [1, 2, 3], 'col2': [4, 5, 6], 'col3': [7, 8, 9]}

# %%
# - - - -

d['col3']
# Out:
# [7, 8, 9]

# %%
d['col1']


# - - - -
# Out:
# [1, 2, 3]

# %%
# - - - -

d['col3'][1]


# *******
# Out:
# 8

# %%
# *******


df_d = pd.DataFrame(d)
df_d

# - - - -
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
# - - - -


df_d['col3']

# - - - -
# Out:
# 0    7
# 1    8
# 2    9
# Name: col3, dtype: int64

# %%
# - - - -

df_d['col3'][1]


# *******
# Out:
# 8

# %%
# *******

df_d.index = ['row1', 'row2', 'row3']

#  show the updated dataframe
df_d

# - - - -
# Out:
#       col1  col2  col3
# row1     1     4     7
# row2     2     5     8
# row3     3     6     9

# %%
# - - - -

df_d['col3']['row2']
# Out:
# 8

# %%
df_d.loc['row2']['col3']

'''
note that in label or location-based indexing, the ROW is the first callable and not the COLUMN:
    Which is unlike the dictionary and pure dataframe calling method, which calls the column first

in Summary:
    Label and Location-based indexing: ROW x COL    hence: df.loc[row][col]
    DF and Dictionary Indexing:        COl x ROW    hence: df[col][row]
'''
# Out:
# '\nnote that in label or location-based indexing, the ROW is the first callable and not the COLUMN:\n    Which is unlike the dictionary and pure dataframe calling method, which calls the column first\n\nin Summary:\n    Label and Location-based indexing: ROW x COL    hence: df.loc[row][col]\n    DF and Dictionary Indexing:        COl x ROW    hence: df[col][row]\n'

# %%
df_d.iloc[1][2]


# *******
# Out:
# 8

# %%
# *******

# - - - -

# %%
# print(df_d.iloc[1][2])
print(df_d.iloc[1,2])
type(df_d.iloc[1][2])



# - - - -
# Out:
# 8
# numpy.int64

# %%
print(df_d.iloc[2])
type(df_d.iloc[2])



# - - - -
# Out:
# col1    3
# col2    6
# col3    9
# Name: row3, dtype: int64
# pandas.core.series.Series

# %%
df_d.iloc[:, [0,2]]
# Out:
#       col1  col3
# row1     1     7
# row2     2     8
# row3     3     9

# %%
#df_d.iloc[[0,1], [1,2]]
df_d.iloc[0:2, 1:3]
type(df_d.iloc[0:2, 1:3])
# Out:
# pandas.core.frame.DataFrame

# %%
df_d.iloc[[0, 2], [0, 2]]
# Out:
#       col1  col3
# row1     1     7
# row3     3     9

# %%
df_d.iloc[:2, [0, 2]]




# - - - -
# Out:
#       col1  col3
# row1     1     7
# row2     2     8

# %%
# - - - -

df_d.loc[['row1', 'row3'], ['col1', 'col3']]
# Out:
#       col1  col3
# row1     1     7
# row3     3     9
